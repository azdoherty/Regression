# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd
import statsmodels.api as sm
import math
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.feature_selection import f_regression
from sklearn.cross_validation import cross_val_score, cross_val_predict

# %%
diabetes = datasets.load_diabetes()

# %%
# View dict elements
diabetes.keys()

# View Data
print(diabetes.data.shape)
col_names = “age sex bmi map tc ldl hdl tch ltg glu”.split()
df = pd.DataFrame(diabetes.data, columns=columns)
y = diabetes.target
sns.pairplot(data_frame)
# Out:
# (442, 10)

# %%
# Check for extreme/suspicious values
for col_name in col_names:
    print(col_name,":",min(data_frame[col_name]),np.percentile(data_frame[col_name], 
        [25, 50, 75]),max(data_frame[col_name]))
# Out:
# V1 : -0.107225631607358 [-0.03729927  0.00538306  0.03807591] 0.110726675453815
# V2 : -0.044641636506989 [-0.04464164 -0.04464164  0.05068012] 0.0506801187398187
# V3 : -0.0902752958985185 [-0.03422907 -0.00728377  0.03124802] 0.17055522598066
# V4 : -0.112399602060758 [-0.03665645 -0.00567061  0.03564384] 0.132044217194516
# V5 : -0.126780669916514 [-0.03424784 -0.00432087  0.02835801] 0.153913713156516
# V6 : -0.115613065979398 [-0.0303584  -0.00381907  0.02984439] 0.198787989657293
# V7 : -0.10230705051742 [-0.03511716 -0.00658447  0.0293115 ] 0.181179060397284
# V8 : -0.076394503750001 [-0.03949338 -0.00259226  0.03430886] 0.185234443260194
# V9 : -0.126097385560409 [-0.03324879 -0.00194763  0.03243323] 0.133598980013008
# V10 : -0.137767225690012 [-0.03317903 -0.0010777   0.02791705] 0.135611830689079

# %%
regr = linear_model.LinearRegression()

# Cross-Validation
scores = cross_val_score(regr, data_frame, y, cv=6)

# %%
# View histogram of outcome variable
plt.hist(np.sqrt(y_train))
# Out:
# (array([ 6., 32., 50., 65., 46., 51., 50., 46., 43., 13.]),
#  array([ 5.        ,  6.36010752,  7.72021505,  9.08032257, 10.4404301 ,
#         11.80053762, 13.16064514, 14.52075267, 15.88086019, 17.24096771,
#         18.60107524]),
#  <a list of 10 Patch objects>)

# %%
# Out:
# 402
